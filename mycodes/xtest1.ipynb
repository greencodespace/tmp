# %%
# %time
# %autosave 100
#matplotlib tk
# %matplotlib inline
#%matplotlib notebook
# Out:
# Wall time: 0 ns
# Autosaving every 100 seconds

# %%
print("Hello Peace World")
print("안녕하세요 평화세상")
# Out:
# Hello Peace World
# 안녕하세요 평화세상

# %%
from numpy import *
from scipy import *
from pylab import *
 

print('hello peace world')
print('%10.5f' % 38)

def myplot(a,b,c):

    fig=figure(facecolor='w');
    x=arange(a,b,c);
    plot(x,sin(x));
    title('sin')
    show();
    del x;

if __name__ == "__main__":

    myplot(0,2*pi,0.1);
# Out:
# hello peace world
#   38.00000
